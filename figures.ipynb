# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys, copy, os, shutil
from tqdm.notebook import tqdm
from IPython.display import clear_output

# load in our logs file
logs = pd.read_csv("aggregate_logs.csv")
logs = logs.query("a == 0.0")

# %%
'''
For each missing data setting + intensity, let's get the best performing variants in terms of 
mean total reward, hyperparameter tuning over eps, alpha, and g
'''

# what are the variables governing our environment? also variables governing our model, and universal hparams
env_params = ["PS", "PW", "MM", "theta", "t-color", "t-in", "t-out"]
model_params = ["IM", "NC", "K", "p-shuf"]
uni_params = ["eps", "a", "g"]
nuisance_params = ["max-iters", "seed"]
metric_params = ["num_episodes", "mean_total_reward", "mean_steps_river", "mean_path_length",
                 "mean_wallclock_time", "mean20_total_reward", "mean20_steps_river",
                 "mean20_path_length", "mean20_wallclock_time"]

# we're only concerned with the mean over 3 seeds
logs = logs.groupby(env_params + model_params + uni_params, dropna=False).mean().reset_index()

# %%
# 1. pretty pictures of the environments with the rewards (1 x 2, side-by-side) COLORED CORRECTLY

# 2. visualize Q function on MCAR + theta=0.4: best joint vs. best baseline (looks like shit) (2x2)
# 2 models, 2 {flood vs. no flood.}

# 3. Lineplot of aggregate results (MCAR + max wind + switch): 1x3 grid of subplots, x-axis=theta 
# y-axis \in {mean_total_reward, mean_steps_river, mean_path_length}, each line is a model (only K=1 and K=10)
# pick best alpha, gamma, epsilon, and p_shuffle (if applicable) for each model

# 4. learning plots over time (MCAR + max_wind + max_switch at theta=0.4): 1x3
# x-axis = timestep -- let's do stepplot to make use of per-episode metrics. 
# y-axis: {reward, river_steps, path_length}, 3 baselines + K={1, 10} x {joint, joint-cons} x {best shuffle}

# 5. MI details -- look at K=1, K=5, K=10 and p-shuffle = 0.1 vs. 0.0
# MCAR at theta=0.4, max_wind and max_switch. x-axis: K=1,5,10, 1 line for p-shuffle 1 line for no-shuffle
# lets do a 1x3 for each metric of {reward, river_steps, path_length}

# 6. Less beautiful-looking things -- Mcolor and Mfog (PS and PW are maxed out.). 2x2
# x-axis: timestep (step function), y-axis: path_length, 
# 3 baselines + K={1, 10} x {joint, joint-cons} x {best shuffle}

# %%
# Out:
#        PS   PW    MM  theta  t-color  t-in  t-out             IM   NC    K  \
# 0     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 1     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 2     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 3     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 4     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# ...   ...  ...   ...    ...      ...   ...    ...            ...  ...  ...
# 3235  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3236  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3237  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3238  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3239  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
#
#       ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 0     ...   1.0      0.000000                NaN               NaN
# 1     ...   1.0      0.000000                NaN               NaN
# 2     ...   1.0      0.000000                NaN               NaN
# 3     ...   1.0     11.000000       -8007.041919        459.227273
# 4     ...   1.0     11.000000       -8007.041919        459.227273
# ...   ...   ...           ...                ...               ...
# 3235  ...   1.0     48.000000       -2271.652190        149.958701
# 3236  ...   1.0     48.000000       -2271.652190        149.958701
# 3237  ...   1.0     60.333333       -1911.805445        131.327353
# 3238  ...   1.0     60.333333       -1911.805445        131.327353
# 3239  ...   1.0     60.333333       -1911.805445        131.327353
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3          3974.996465            32.241818         -8007.041919
# 4          3974.996465            31.768138         -8007.041919
# ...                ...                  ...                  ...
# 3235       1023.023879             7.606696         -2407.250000
# 3236       1023.023879             7.706984         -2407.250000
# 3237        830.859265             6.516143         -1660.066667
# 3238        830.859265             6.500699         -1660.066667
# 3239        830.859265             6.307900         -1660.066667
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3             459.227273         3974.996465              32.241818
# 4             459.227273         3974.996465              31.768138
# ...                  ...                 ...                    ...
# 3235          158.366667         1082.950000               8.072081
# 3236          158.366667         1082.950000               8.166112
# 3237          114.133333          733.866667               5.882746
# 3238          114.133333          733.866667               5.828956
# 3239          114.133333          733.866667               5.639329
#
# [3240 rows x 25 columns]

# %%
# PS: 0 vs. 0.1, PW: 0 vs. 0.1
# MCAR + {0.0, 0.05, 0.1, 0.2, 0.4}, Mfog + {2 variants}, Mcolor + {2 variants}
# gamma: {1.0, 0.5, 0.0}, alpha: {1.0, SW boobooed}, epsilon: {0.0, 0.05} -- just take whatever performed best.

# %%
logs.query("`t-in` == 0.25 and PS == 0.1 and PW == 0.1")\
.sort_values(by="mean_total_reward").head(20)
# Out:
#        PS   PW    MM  theta  t-color  t-in  t-out                  IM   NC  \
# 3092  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3091  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3090  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3128  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3127  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3126  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3079  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3114  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3115  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3116  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3080  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3078  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3086  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3085  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3084  0.1  0.1  Mfog    NaN      NaN  0.25    0.1               joint  1.0
# 3120  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3121  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3122  0.1  0.1  Mfog    NaN      NaN  0.25    0.1  joint-conservative  1.0
# 3133  0.1  0.1  Mfog    NaN      NaN  0.25    0.1           last-fobs  NaN
# 3140  0.1  0.1  Mfog    NaN      NaN  0.25    0.1       missing-state  NaN
#
#          K  ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 3092  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3091  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3090  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3128  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3127  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3126  10.0  ...   1.0     34.000000       -3167.797120        199.298245
# 3079   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3114   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3115   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3116   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3080   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3078   5.0  ...   1.0     38.333333       -2913.400687        186.286962
# 3086  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3085  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3084  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3120  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3121  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3122  10.0  ...   1.0     43.333333       -2637.460803        177.882167
# 3133   NaN  ...   1.0     40.333333       -2571.364811        161.212216
# 3140   NaN  ...   1.0     40.333333       -2571.364811        161.212216
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 3092       1475.112918           112.618417         -3105.216667
# 3091       1475.112918           113.787003         -3105.216667
# 3090       1475.112918           116.226653         -3105.216667
# 3128       1475.112918           112.091131         -3105.216667
# 3127       1475.112918           111.798938         -3105.216667
# 3126       1475.112918           113.572385         -3105.216667
# 3079       1337.818026            59.095469         -3038.450000
# 3114       1337.818026            51.304049         -3038.450000
# 3115       1337.818026            57.264882         -3038.450000
# 3116       1337.818026            56.858065         -3038.450000
# 3080       1337.818026            54.449404         -3038.450000
# 3078       1337.818026            51.140721         -3038.450000
# 3086       1137.521297            87.095097         -2658.283333
# 3085       1137.521297            87.591614         -2658.283333
# 3084       1137.521297            90.166482         -2658.283333
# 3120       1137.521297            87.608571         -2658.283333
# 3121       1137.521297            86.857390         -2658.283333
# 3122       1137.521297            86.787702         -2658.283333
# 3133       1221.454868             9.468140         -2689.416667
# 3140       1221.454868            15.648676         -2689.416667
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 3092          194.350000         1457.066667             110.892861
# 3091          194.350000         1457.066667             112.472425
# 3090          194.350000         1457.066667             114.763261
# 3128          194.350000         1457.066667             110.730260
# 3127          194.350000         1457.066667             110.608356
# 3126          194.350000         1457.066667             112.293089
# 3079          191.333333         1417.450000              62.673050
# 3114          191.333333         1417.450000              54.335600
# 3115          191.333333         1417.450000              59.968584
# 3116          191.333333         1417.450000              59.726750
# 3080          191.333333         1417.450000              57.636519
# 3078          191.333333         1417.450000              54.157627
# 3086          176.866667         1167.483333              89.338176
# 3085          176.866667         1167.483333              90.007817
# 3084          176.866667         1167.483333              92.851186
# 3120          176.866667         1167.483333              89.835413
# 3121          176.866667         1167.483333              88.951756
# 3122          176.866667         1167.483333              89.002569
# 3133          169.933333         1261.016667               9.795120
# 3140          169.933333         1261.016667              16.134976
#
# [20 rows x 25 columns]

# %%
logs.query("`t-color` == 0.1 and PS == 0.1 and PW == 0.1")\
.sort_values(by="mean_total_reward").head(20)
# Out:
#        PS   PW      MM  theta  t-color  t-in  t-out                  IM   NC  \
# 2970  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 3013  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3012  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3008  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3007  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3006  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 2978  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 3014  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 2976  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2977  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2971  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2972  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2994  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2996  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 2995  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 3030  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3032  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3031  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN  joint-conservative  1.0
# 3002  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
# 3001  0.1  0.1  Mcolor    NaN      0.1   NaN    NaN               joint  1.0
#
#          K  ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 2970   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3013   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3012   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3008   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3007   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3006   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2978   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 3014   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2976   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2977   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2971   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2972   1.0  ...   1.0     36.000000       -2962.739719        191.672186
# 2994  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 2996  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 2995  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 3030  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 3032  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 3031  10.0  ...   1.0     37.666667       -2871.515834        183.131901
# 3002  10.0  ...   1.0     40.000000       -2839.557533        186.550484
# 3001  10.0  ...   1.0     40.000000       -2839.557533        186.550484
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 2970       1338.690043            10.778019         -2717.683333
# 3013       1338.690043            10.220634         -2717.683333
# 3012       1338.690043            10.633870         -2717.683333
# 3008       1338.690043            10.455230         -2717.683333
# 3007       1338.690043            10.496097         -2717.683333
# 3006       1338.690043            10.760840         -2717.683333
# 2978       1338.690043            10.464280         -2717.683333
# 3014       1338.690043            10.439354         -2717.683333
# 2976       1338.690043            10.728194         -2717.683333
# 2977       1338.690043            10.439723         -2717.683333
# 2971       1338.690043            10.525935         -2717.683333
# 2972       1338.690043            10.559406         -2717.683333
# 2994       1324.328726           104.539399         -2779.733333
# 2996       1324.328726           100.887277         -2779.733333
# 2995       1324.328726           102.126790         -2779.733333
# 3030       1324.328726           103.105715         -2779.733333
# 3032       1324.328726           101.721677         -2779.733333
# 3031       1324.328726           100.067377         -2779.733333
# 3002       1261.603181            96.437329         -2533.416667
# 3001       1261.603181            97.732003         -2533.416667
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 2970          179.766667         1200.783333               9.699498
# 3013          179.766667         1200.783333               9.162026
# 3012          179.766667         1200.783333               9.548823
# 3008          179.766667         1200.783333               9.377126
# 3007          179.766667         1200.783333               9.424200
# 3006          179.766667         1200.783333               9.660813
# 2978          179.766667         1200.783333               9.414179
# 3014          179.766667         1200.783333               9.392675
# 2976          179.766667         1200.783333               9.650713
# 2977          179.766667         1200.783333               9.388127
# 2971          179.766667         1200.783333               9.477402
# 2972          179.766667         1200.783333               9.496894
# 2994          175.100000         1304.833333             103.254325
# 2996          175.100000         1304.833333              99.451089
# 2995          175.100000         1304.833333             100.722928
# 3030          175.100000         1304.833333             101.465658
# 3032          175.100000         1304.833333             100.249246
# 3031          175.100000         1304.833333              98.463809
# 3002          174.700000         1062.116667              81.324037
# 3001          174.700000         1062.116667              82.385222
#
# [20 rows x 25 columns]

# %%
logs.query("`t-color` == 0.0 and PS == 0.1 and PW == 0.1")\
.sort_values(by="mean_total_reward").head(20)
# Out:
#        PS   PW      MM  theta  t-color  t-in  t-out                  IM   NC  \
# 2930  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2929  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2928  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2894  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2893  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2892  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2880  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2923  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2922  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2918  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2917  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2916  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2924  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2888  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2887  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2882  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2886  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2881  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN               joint  1.0
# 2940  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
# 2942  0.1  0.1  Mcolor    NaN      0.0   NaN    NaN  joint-conservative  1.0
#
#          K  ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 2930   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2929   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2928   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2894   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2893   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2892   5.0  ...   1.0     38.333333       -2808.478741        181.949495
# 2880   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2923   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2922   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2918   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2917   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2916   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2924   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2888   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2887   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2882   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2886   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2881   1.0  ...   1.0     40.000000       -2661.544974        168.390212
# 2940  10.0  ...   1.0     39.666667       -2597.993651        167.155556
# 2942  10.0  ...   1.0     39.666667       -2597.993651        167.155556
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 2930       1271.933286            52.349906         -2940.966667
# 2929       1271.933286            56.869890         -2940.966667
# 2928       1271.933286            48.890852         -2940.966667
# 2894       1271.933286            51.541914         -2940.966667
# 2893       1271.933286            56.515392         -2940.966667
# 2892       1271.933286            49.939450         -2940.966667
# 2880       1247.033069             9.794437         -2523.683333
# 2923       1247.033069             9.496928         -2523.683333
# 2922       1247.033069             9.645071         -2523.683333
# 2918       1247.033069             9.691133         -2523.683333
# 2917       1247.033069             9.663712         -2523.683333
# 2916       1247.033069             9.802535         -2523.683333
# 2924       1247.033069             9.659138         -2523.683333
# 2888       1247.033069             9.704830         -2523.683333
# 2887       1247.033069             9.715171         -2523.683333
# 2882       1247.033069             9.761676         -2523.683333
# 2886       1247.033069             9.891166         -2523.683333
# 2881       1247.033069             9.723468         -2523.683333
# 2940       1194.593651            91.147347         -2609.100000
# 2942       1194.593651            91.124958         -2609.100000
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 2930          188.216667         1348.016667              55.771753
# 2929          188.216667         1348.016667              60.309951
# 2928          188.216667         1348.016667              51.769567
# 2894          188.216667         1348.016667              54.637806
# 2893          188.216667         1348.016667              59.969268
# 2892          188.216667         1348.016667              52.992981
# 2880          162.150000         1165.333333               9.149413
# 2923          162.150000         1165.333333               8.883409
# 2922          162.150000         1165.333333               9.013811
# 2918          162.150000         1165.333333               9.056673
# 2917          162.150000         1165.333333               9.028205
# 2916          162.150000         1165.333333               9.176407
# 2924          162.150000         1165.333333               9.020326
# 2888          162.150000         1165.333333               9.068509
# 2887          162.150000         1165.333333               9.066968
# 2882          162.150000         1165.333333               9.129226
# 2886          162.150000         1165.333333               9.249359
# 2881          162.150000         1165.333333               9.063925
# 2940          172.066667         1161.500000              88.589840
# 2942          172.066667         1161.500000              88.470590
#
# [20 rows x 25 columns]

# %%
logs.query()
# Out:
#        PS   PW    MM  theta  t-color  t-in  t-out             IM   NC    K  \
# 0     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 1     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 2     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 3     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 4     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# ...   ...  ...   ...    ...      ...   ...    ...            ...  ...  ...
# 3235  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3236  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3237  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3238  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3239  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
#
#       ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 0     ...   1.0      0.000000                NaN               NaN
# 1     ...   1.0      0.000000                NaN               NaN
# 2     ...   1.0      0.000000                NaN               NaN
# 3     ...   1.0     11.000000       -8007.041919        459.227273
# 4     ...   1.0     11.000000       -8007.041919        459.227273
# ...   ...   ...           ...                ...               ...
# 3235  ...   1.0     48.000000       -2271.652190        149.958701
# 3236  ...   1.0     48.000000       -2271.652190        149.958701
# 3237  ...   1.0     60.333333       -1911.805445        131.327353
# 3238  ...   1.0     60.333333       -1911.805445        131.327353
# 3239  ...   1.0     60.333333       -1911.805445        131.327353
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3          3974.996465            32.241818         -8007.041919
# 4          3974.996465            31.768138         -8007.041919
# ...                ...                  ...                  ...
# 3235       1023.023879             7.606696         -2407.250000
# 3236       1023.023879             7.706984         -2407.250000
# 3237        830.859265             6.516143         -1660.066667
# 3238        830.859265             6.500699         -1660.066667
# 3239        830.859265             6.307900         -1660.066667
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3             459.227273         3974.996465              32.241818
# 4             459.227273         3974.996465              31.768138
# ...                  ...                 ...                    ...
# 3235          158.366667         1082.950000               8.072081
# 3236          158.366667         1082.950000               8.166112
# 3237          114.133333          733.866667               5.882746
# 3238          114.133333          733.866667               5.828956
# 3239          114.133333          733.866667               5.639329
#
# [3240 rows x 25 columns]

# %%
logs.query("IM == 'missing-state'").sort_values("mean_total_reward", ascending=False)
# Out:
#        PS   PW      MM  theta  t-color  t-in  t-out             IM  NC   K  \
# 1251  0.0  0.1    MCAR    0.4      NaN   NaN    NaN  missing-state NaN NaN
# 1071  0.0  0.1    MCAR    0.1      NaN   NaN    NaN  missing-state NaN NaN
# 1432  0.0  0.1  Mcolor    NaN      0.1   NaN    NaN  missing-state NaN NaN
# 1431  0.0  0.1  Mcolor    NaN      0.1   NaN    NaN  missing-state NaN NaN
# 1343  0.0  0.1  Mcolor    NaN      0.0   NaN    NaN  missing-state NaN NaN
# ...   ...  ...     ...    ...      ...   ...    ...            ...  ..  ..
# 2329  0.1  0.0    Mfog    NaN      NaN  0.25    0.1  missing-state NaN NaN
# 2330  0.1  0.0    Mfog    NaN      NaN  0.25    0.1  missing-state NaN NaN
# 2418  0.1  0.0    Mfog    NaN      NaN  0.50    0.0  missing-state NaN NaN
# 2419  0.1  0.0    Mfog    NaN      NaN  0.50    0.0  missing-state NaN NaN
# 2420  0.1  0.0    Mfog    NaN      NaN  0.50    0.0  missing-state NaN NaN
#
#       ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 1251  ...   1.0     52.333333       -1940.209443        121.095036
# 1071  ...   1.0     52.333333       -1940.209443        121.095036
# 1432  ...   1.0     52.333333       -1940.209443        121.095036
# 1431  ...   1.0     52.333333       -1940.209443        121.095036
# 1343  ...   1.0     52.333333       -1940.209443        121.095036
# ...   ...   ...           ...                ...               ...
# 2329  ...   1.0      0.000000                NaN               NaN
# 2330  ...   1.0      0.000000                NaN               NaN
# 2418  ...   1.0      0.000000                NaN               NaN
# 2419  ...   1.0      0.000000                NaN               NaN
# 2420  ...   1.0      0.000000                NaN               NaN
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 1251        951.354116            12.297618         -1613.683333
# 1071        951.354116            12.502689         -1613.683333
# 1432        951.354116            13.086207         -1613.683333
# 1431        951.354116            15.228258         -1613.683333
# 1343        951.354116            12.898148         -1613.683333
# ...                ...                  ...                  ...
# 2329               NaN                  NaN                  NaN
# 2330               NaN                  NaN                  NaN
# 2418               NaN                  NaN                  NaN
# 2419               NaN                  NaN                  NaN
# 2420               NaN                  NaN                  NaN
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 1251          100.233333          812.583333              10.686564
# 1071          100.233333          812.583333              10.871584
# 1432          100.233333          812.583333              11.360300
# 1431          100.233333          812.583333              13.207655
# 1343          100.233333          812.583333              11.112496
# ...                  ...                 ...                    ...
# 2329                 NaN                 NaN                    NaN
# 2330                 NaN                 NaN                    NaN
# 2418                 NaN                 NaN                    NaN
# 2419                 NaN                 NaN                    NaN
# 2420                 NaN                 NaN                    NaN
#
# [216 rows x 25 columns]

# %%
logs.groupby(env_params + model_params + uni_params, dropna=False).mean().reset_index()
# Out:
#        PS   PW    MM  theta  t-color  t-in  t-out             IM   NC    K  \
# 0     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 1     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 2     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 3     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# 4     0.0  0.0  MCAR    0.0      NaN   NaN    NaN          joint  1.0  1.0
# ...   ...  ...   ...    ...      ...   ...    ...            ...  ...  ...
# 3235  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3236  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3237  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3238  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
# 3239  0.1  0.1  Mfog    NaN      NaN   0.5    0.0  random-action  NaN  NaN
#
#       ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 0     ...   1.0      0.000000                NaN               NaN
# 1     ...   1.0      0.000000                NaN               NaN
# 2     ...   1.0      0.000000                NaN               NaN
# 3     ...   1.0     11.000000       -8007.041919        459.227273
# 4     ...   1.0     11.000000       -8007.041919        459.227273
# ...   ...   ...           ...                ...               ...
# 3235  ...   1.0     48.000000       -2271.652190        149.958701
# 3236  ...   1.0     48.000000       -2271.652190        149.958701
# 3237  ...   1.0     60.333333       -1911.805445        131.327353
# 3238  ...   1.0     60.333333       -1911.805445        131.327353
# 3239  ...   1.0     60.333333       -1911.805445        131.327353
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3          3974.996465            32.241818         -8007.041919
# 4          3974.996465            31.768138         -8007.041919
# ...                ...                  ...                  ...
# 3235       1023.023879             7.606696         -2407.250000
# 3236       1023.023879             7.706984         -2407.250000
# 3237        830.859265             6.516143         -1660.066667
# 3238        830.859265             6.500699         -1660.066667
# 3239        830.859265             6.307900         -1660.066667
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3             459.227273         3974.996465              32.241818
# 4             459.227273         3974.996465              31.768138
# ...                  ...                 ...                    ...
# 3235          158.366667         1082.950000               8.072081
# 3236          158.366667         1082.950000               8.166112
# 3237          114.133333          733.866667               5.882746
# 3238          114.133333          733.866667               5.828956
# 3239          114.133333          733.866667               5.639329
#
# [3240 rows x 25 columns]

# %%
# group by environment and base model
best_logs = logs.sort_values(by="mean_total_reward", ascending=False)\
.groupby(env_params + model_params + ["seed"], dropna=False).first().reset_index()

# %%
logs.groupby(env_params + model_params + uni_params, dropna=False).mean().reset_index()\
.query("PS == 0.1 and PW == 0.1 and MM == 'MCAR' and theta == 0.4")\
.sort_values(by="mean20_path_length").query("`p-shuf` == 0.1")
# Out:
#        PS   PW    MM  theta  t-color  t-in  t-out                  IM   NC  \
# 5621  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# 5651  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# 5644  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# 5627  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# 5626  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# ...   ...  ...   ...    ...      ...   ...    ...                 ...  ...
# 5712  0.1  0.1  MCAR    0.4      NaN   NaN    NaN  joint-conservative  1.0
# 5715  0.1  0.1  MCAR    0.4      NaN   NaN    NaN  joint-conservative  1.0
# 5673  0.1  0.1  MCAR    0.4      NaN   NaN    NaN  joint-conservative  1.0
# 5595  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
# 5601  0.1  0.1  MCAR    0.4      NaN   NaN    NaN               joint  1.0
#
#          K  ...  seed  num_episodes  mean_total_reward  mean_steps_river  \
# 5621   5.0  ...   1.0   4827.000000          79.587514          1.217072
# 5651  10.0  ...   1.0   4554.666667          73.451192          1.839328
# 5644  10.0  ...   1.0   3270.000000          78.299606          0.816176
# 5627   5.0  ...   1.0   4365.333333          77.026303          1.390494
# 5626   5.0  ...   1.0   2382.666667          70.734988          1.028170
# ...    ...  ...   ...           ...                ...               ...
# 5712  10.0  ...   1.0     36.000000       -3040.557041        196.402496
# 5715  10.0  ...   1.0     43.333333        -736.671939          5.693342
# 5673   1.0  ...   1.0     14.000000       -2636.174603         20.886243
# 5595   1.0  ...   1.0     11.666667       -2630.072751         16.642857
# 5601   1.0  ...   1.0      9.666667       -4032.102564         26.691901
#
#       mean_path_length  mean_wallclock_time  mean20_total_reward  \
# 5621         10.458837             0.524983            75.983333
# 5651         10.994856             0.966935            72.750000
# 5644         15.354806             1.382801            81.200000
# 5627         11.459255             0.586693            75.600000
# 5626         21.011481             1.117321            78.400000
# ...                ...                  ...                  ...
# 5712       1373.934581           107.185355         -2981.150000
# 5715        786.431864            71.653182         -1491.950000
# 5673       2549.198413            23.341778         -2636.174603
# 5595       2581.287037            23.460455         -2630.072751
# 5601       3892.875458            35.588953         -4032.102564
#
#       mean20_steps_river  mean20_path_length  mean20_wallclock_time
# 5621            1.700000            9.716667               0.487950
# 5651            2.016667           10.100000               0.889966
# 5644            0.683333           13.650000               1.235317
# 5627            1.300000           13.700000               0.702916
# 5626            0.966667           13.900000               0.742031
# ...                  ...                 ...                    ...
# 5712          193.333333         1342.150000             104.777549
# 5715            3.433333         1562.050000             142.908998
# 5673           20.886243         2549.198413              23.341778
# 5595           16.642857         2581.287037              23.460455
# 5601           26.691901         3892.875458              35.588953
#
# [72 rows x 25 columns]

# %%
logs.columns
# Out:
# Index(['PS', 'PW', 'MM', 'theta', 't-color', 't-in', 't-out', 'IM', 'NC', 'K',
#        'p-shuf', 'max-iters', 'eps', 'a', 'g', 'seed', 'num_episodes',
#        'mean_total_reward', 'mean_steps_river', 'mean_path_length',
#        'mean_wallclock_time', 'mean20_total_reward', 'mean20_steps_river',
#        'mean20_path_length', 'mean20_wallclock_time'],
#       dtype='object')
